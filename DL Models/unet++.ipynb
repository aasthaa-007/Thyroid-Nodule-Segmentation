# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
from tensorflow.keras import backend as K
from google.colab.patches import cv2_imshow

# %%
import os

import numpy as np
import cv2
import matplotlib.pyplot as plt

from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras import backend as keras
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, LearningRateScheduler

from glob import glob
from tqdm import tqdm

# %%
path = '/content/drive/MyDrive/research/segmentation/train++/augmentation'
os.mkdir(path)

path = '/content/drive/MyDrive/research/segmentation/test++'
os.mkdir(path)

path = '/content/drive/MyDrive/research/segmentation/train++/dilate'
os.mkdir(path)

path = '/content/drive/MyDrive/research/segmentation/train++/image'
os.mkdir(path)

path = '/content/drive/MyDrive/research/segmentation/train++/mask'
os.mkdir(path)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-4-72f67524deeb> in <cell line: 2>()
#       1 path = '/content/drive/MyDrive/research2/segmentation/train++/augmentation'
# ----> 2 os.mkdir(path)
#
# FileExistsError: [Errno 17] File exists: '/content/drive/MyDrive/research2/segmentation/train++/augmentation'

# %%
input_dir = os.path.join('/content','drive','MyDrive','research')
segmentation_dir = os.path.join(input_dir,'segmentation')
segmentation_test_dir = os.path.join(segmentation_dir,'test++')
segmentation_train_dir = os.path.join(segmentation_dir,'train++')
segmentation_aug_dir = os.path.join(segmentation_train_dir,'augmentation')
segmentation_image_dir = os.path.join(segmentation_train_dir,'image')
segmentation_mask_dir= os.path.join(segmentation_train_dir,"mask")
segmentation_dilate_dir = os.path.join(segmentation_train_dir,"dilate")
DDTI_train_dir = os.path.join(input_dir,"Thyroid_files")
DDTI_image_dir = os.path.join(DDTI_train_dir,"ultrasound_png")
DDTI_mask_dir = os.path.join(DDTI_train_dir,"mask","mask1")
DILATE_KERNEL = np.ones((15, 15), np.uint8)
BATCH_SIZE=2
EPOCHS=60

# %%
train_dir_1 = glob(os.path.join(segmentation_dir,'train++','image',"*.png"))
file=len(train_dir_1)
file
test_dir_1 = glob(os.path.join(segmentation_dir,'test++',"*.png"))
file1=len(test_dir_1)
file1
# Out:
# 0

# %%
  def add_colored_dilate(image,mask_image,dilate_image):
     mask_image_gray = cv2.cvtColor(mask_image,cv2.COLOR_BGR2GRAY)
     dilate_image_gray = cv2.cvtColor(dilate_image,cv2.COLOR_BGR2GRAY)
     mask = cv2.bitwise_and(mask_image,mask_image,mask=mask_image_gray)
     dilate = cv2.bitwise_and(dilate_image,dilate_image,mask=dilate_image_gray)
     mask_coord = np.where(mask!=[0,0,0])
     dilate_coord = np.where(dilate!=[0,0,0])

     mask[mask_coord[0],mask_coord[1],:] = [255,0,0]
     dilate[dilate_coord[0],dilate_coord[1],:] = [0,0,255]

     ret = cv2.addWeighted(image,0.7,dilate,0.3,0)
     ret = cv2.addWeighted(ret,0.7,mask,0.3,0)

     return ret
  def add_colored_mask(image,mask_image):
    mask_image_grey = cv2.cvtColor(mask_image,cv2.COLOR_BGR2GRAY)

    mask = cv2.bitwise_and(mask_image,mask_image,mask=mask_image_grey)

    mask_coord = np.where(mask!=[0,0,0])

    mask[mask_coord[0],mask_coord[1],:] = [255,0,0]

    ret = cv2.addWeighted(image,0.7,mask,0.3,0)

    return ret
  def diff_mask(ref_image,mask_image):
    mask_image_gray = cv2.cvtColor(mask_image,cv2.COLOR_BGR2GRAY)

    mask = cv2.bitwise_and(mask_image,mask_image,mask=mask_image_gray)

    mask_coord = np.where(mask!=[0,0,0])

    mask[mask_coord[0],mask_coord[1],:] = [255,0,0]

    ret = cv2.addWeighted(ref_image,0.7,mask,0.3,0)
    return ret

# %%
DDTI_mask_dir_1 = glob(os.path.join(DDTI_mask_dir,'*.png'))
DDTI_test = DDTI_mask_dir_1[0:62]
DDTI_train = DDTI_mask_dir_1[62:]
for mask_file in tqdm(DDTI_mask_dir_1):
  base_file = os.path.basename(mask_file).replace("_mask","")
  image_file = os.path.join(DDTI_image_dir,base_file)
  # print(mask_file)
  image = cv2.imread(image_file)
  # cv2_imshow(image)
  mask = cv2.imread(mask_file,cv2.IMREAD_GRAYSCALE)
  # cv2_imshow(mask)
  # image = cv2.resize(image,(512,512))
  # mask = cv2.resize(mask,(512,512))

  mask_dilate = cv2.dilate(mask,DILATE_KERNEL,iterations=1)

  if (mask_file in DDTI_train):
        cv2.imwrite(os.path.join(segmentation_image_dir , base_file), \
                    image)
        cv2.imwrite(os.path.join(segmentation_mask_dir, base_file), \
                    mask)
        cv2.imwrite(os.path.join(segmentation_dilate_dir, base_file), \
                    mask_dilate)

  else:
    filename,fileext = os.path.splitext(base_file)
    cv2.imwrite(os.path.join(segmentation_test_dir, base_file), \
                    image)
    cv2.imwrite(os.path.join(segmentation_test_dir, \
                                 "%s_mask%s" % (filename, fileext)), mask)
    cv2.imwrite(os.path.join(segmentation_test_dir, \
                                 "%s_dilate%s" % (filename, fileext)), mask_dilate)
# Out:
# 100%|██████████| 306/306 [03:31<00:00,  1.45it/s]

# %%
DDTI_mask_dir_1
# Out:
# ['/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/10.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/100.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/101.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/102.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/103.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/104.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/105.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/107.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/108.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/109.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/11.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/110.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/112.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/111.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/113.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/115.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/116.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/118.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/117.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/12.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/119.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/121.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/123.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/124.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/125.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/128.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/126.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/13.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/131.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/133.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/134.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/135.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/136.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/137.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/14.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/141.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/143.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/140.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/144.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/145.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/147.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/148.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/149.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/15.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/151.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/150.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/152.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/153.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/154.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/16.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/159.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/155.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/161.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/160.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/162.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/164.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/167.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/169.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/168.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/17.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/170.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/171.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/178.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/172.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/174.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/179.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/18.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/180.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/182.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/181.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/184.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/185.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/186.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/187.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/188.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/19.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/190.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/192.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/193.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/194.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/195.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/196.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/199.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/2.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/200.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/20.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/201.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/202.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/204.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/206.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/207.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/21.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/208.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/211.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/212.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/214.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/215.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/216.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/217.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/219.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/220.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/22.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/221.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/223.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/222.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/224.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/228.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/229.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/226.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/231.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/23.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/232.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/236.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/235.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/237.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/238.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/239.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/24.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/240.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/241.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/242.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/244.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/243.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/245.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/246.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/247.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/248.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/249.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/25.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/250.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/252.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/251.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/253.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/254.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/256.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/255.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/257.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/258.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/259.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/26.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/260.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/261.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/263.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/262.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/265.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/264.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/268.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/267.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/269.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/27.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/271.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/270.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/272.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/273.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/274.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/275.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/276.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/277.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/278.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/279.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/280.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/28.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/281.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/282.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/283.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/284.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/285.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/286.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/287.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/289.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/29.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/288.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/290.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/292.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/291.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/293.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/295.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/297.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/298.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/299.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/30.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/3.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/301.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/300.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/302.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/304.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/303.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/307.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/306.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/305.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/308.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/309.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/311.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/31.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/310.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/314.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/312.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/316.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/32.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/320.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/326.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/321.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/323.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/329.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/331.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/33.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/332.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/333.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/339.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/34.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/342.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/340.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/341.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/343.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/345.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/344.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/346.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/348.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/352.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/35.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/349.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/354.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/355.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/356.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/357.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/361.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/36.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/363.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/362.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/368.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/364.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/365.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/369.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/370.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/372.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/376.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/374.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/375.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/377.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/378.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/380.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/382.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/379.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/38.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/383.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/388.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/39.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/384.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/386.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/394.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/390.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/392.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/398.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/396.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/397.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/4.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/399.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/40.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/41.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/400.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/43.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/42.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/44.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/47.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/46.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/45.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/48.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/49.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/5.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/52.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/53.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/50.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/51.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/55.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/56.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/59.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/57.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/60.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/6.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/61.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/63.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/66.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/67.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/68.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/7.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/70.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/72.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/71.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/73.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/74.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/77.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/76.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/78.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/79.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/8.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/82.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/83.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/84.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/86.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/87.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/89.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/94.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/9.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/91.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/95.png',
#  '/content/drive/MyDrive/research2/ChinaSet_AllFiles/mask/mask1/98.png']

# %%
base_file = os.path.basename(DDTI_train[0].replace("_mask",""))
image_file = os.path.join(segmentation_image_dir,base_file)
mask_image_file = os.path.join(segmentation_dilate_dir,base_file)
dilate_image_file = os.path.join(segmentation_dilate_dir,base_file)
image = cv2.imread(image_file)
mask_image = cv2.imread(mask_image_file)
dilate_image = cv2.imread(dilate_image_file)
merged_image = add_colored_dilate(image,mask_image,dilate_image)
fig,axs = plt.subplots(2,4,figsize=(15,8))

axs[0, 0].set_title("Ultrasoud")
axs[0, 0].imshow(image)

axs[0, 1].set_title("Mask")
axs[0, 1].imshow(mask_image)

axs[0, 2].set_title("Dilate")
axs[0, 2].imshow(dilate_image)

axs[0, 3].set_title("Merged")
axs[0, 3].imshow(merged_image)

base_file = os.path.basename(DDTI_test[0].replace("_mask",""))
image_file = os.path.join(segmentation_test_dir,base_file)
filename,fileext = os.path.splitext(base_file)
mask_image_file = os.path.join(segmentation_test_dir, \
                               "%s_mask%s" % (filename, fileext))

filename, fileext = os.path.splitext(base_file)
image_file = os.path.join(segmentation_test_dir, base_file)
mask_image_file = os.path.join(segmentation_test_dir, \
                               "%s_mask%s" % (filename, fileext))
dilate_image_file = os.path.join(segmentation_test_dir, \
                                 "%s_dilate%s" % (filename, fileext))
image = cv2.imread(image_file)
mask_image = cv2.imread(mask_image_file)
dilate_image = cv2.imread(dilate_image_file)
merged_image = add_colored_dilate(image, mask_image, dilate_image)

axs[1, 0].set_title("Ultrasound")
axs[1, 0].imshow(image)

axs[1, 1].set_title("Mask")
axs[1, 1].imshow(mask_image)

axs[1, 2].set_title("Dilate")
axs[1, 2].imshow(dilate_image)

axs[1, 3].set_title("Merged")
axs[1, 3].imshow(merged_image)

# %%
train_files = glob(os.path.join(segmentation_image_dir, "*.png"))
test_files = glob(os.path.join(segmentation_test_dir, "*.png"))
mask_files = glob(os.path.join(segmentation_mask_dir, "*.png"))
dilate_files = glob(os.path.join(segmentation_dilate_dir, "*.png"))

(len(train_files), \
 len(test_files), \
 len(mask_files), \
 len(dilate_files))
# Out:
# (244, 186, 244, 244)

# %%
def train_generator(batch_size, train_path, image_folder, mask_folder, aug_dict,
        image_color_mode="grayscale",
        mask_color_mode="grayscale",
        image_save_prefix="image",
        mask_save_prefix="mask",
        save_to_dir=None,
        target_size=(256,256),
        seed=1):

    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)

    image_generator = image_datagen.flow_from_directory(
        train_path,
        classes = [image_folder],
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed)

    mask_generator = mask_datagen.flow_from_directory(
        train_path,
        classes = [mask_folder],
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed)

    train_gen = zip(image_generator, mask_generator)

    for (img, mask) in train_gen:
        img, mask = adjust_data(img, mask)
        yield (img,mask)

def adjust_data(img,mask):
    img = img / 255
    mask = mask / 255
    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0

    return (img, mask)

# %%
def mean_iou(y_true, y_pred):
    true_positives=tf.reduce_sum(tf.round(K.clip(y_true*y_pred, 0, 1)))
    true_negatives=tf.reduce_sum(K.round(K.clip((1-y_true)*(1-y_pred), 0, 1)))
    possible_negatives=tf.reduce_sum(K.round(K.clip((1-y_true), 0, 1)))
    possible_positives=tf.reduce_sum(tf.round(K.clip(y_true, 0, 1)))
    iou = (true_positives)/(possible_negatives - true_negatives + possible_positives + K.epsilon())
    return K.mean(iou)

def sensitivity(y_true,y_pred):
    true_positives=tf.reduce_sum(tf.round(K.clip(y_true*y_pred, 0, 1)))
    possible_positives=tf.reduce_sum(tf.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives+K.epsilon())

def specificity(y_true,y_pred):
    true_negatives=tf.reduce_sum(K.round(K.clip((1-y_true)*(1-y_pred), 0, 1)))
    possible_negatives=tf.reduce_sum(K.round(K.clip((1-y_true), 0, 1)))
    return true_negatives / (possible_negatives+K.epsilon())

def precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def recall(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

# %%
def dice_coef(y_true, y_pred):
    y_true_f = keras.flatten(y_true)
    y_pred_f = keras.flatten(y_pred)
    intersection = keras.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (keras.sum(y_true_f) + keras.sum(y_pred_f) + 1)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %%
def unet_plus (input_size=(256,256,1)):
  inputs = Input(input_size)

# %%
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, concatenate, Conv2DTranspose
from tensorflow.keras.initializers import he_normal

def unet_plus(input_size=(256, 256, 1), num_classes=1, activation='relu'):
    inputs = Input(input_size)

    # First block
    conv1_1 = Conv2D(32, (3,3), activation=activation, kernel_initializer=he_normal(), padding='same')(inputs)
    conv1_1 = Conv2D(32, (3,3), activation=activation, kernel_initializer=he_normal(), padding='same')(conv1_1)
    pool1 = MaxPooling2D((2,2), strides=(2,2))(conv1_1)

    # Second block
    conv2_1 = Conv2D(64, (3,3), activation=activation, kernel_initializer=he_normal(), padding='same')(pool1)
    conv2_1 = Conv2D(64, (3,3), activation=activation, kernel_initializer=he_normal(), padding='same')(conv2_1)
    pool2 = MaxPooling2D((2,2), strides=(2,2))(conv2_1)

    # Third block
    conv3_1 = Conv2D(128, (3,3), activation=activation, kernel_initializer=he_normal(), padding='same')(pool2)
    conv3_1 = Conv2D(128, (3,3), activation=activation, kernel_initializer=he_normal(), padding='same')(conv3_1)
    pool3 = MaxPooling2D((2,2), strides=(2,2))(conv3_1)

    # Fourth block
    conv4_1 = Conv2D(256, (3,3), activation=activation, kernel_initializer=he_normal(), padding='same')(pool3)
    conv4_1 = Conv2D(256, (3,3), activation=activation, kernel_initializer=he_normal(), padding='same')(conv4_1)
    pool4 = MaxPooling2D((2,2), strides=(2,2))(conv4_1)

    # Fifth block
    conv5_1 = Conv2D(512, (3,3), activation=activation, kernel_initializer=he_normal(), padding='same')(pool4)
    conv5_1 = Conv2D(512, (3,3), activation=activation, kernel_initializer=he_normal(), padding='same')(conv5_1)

    # Fourth block upsampling
    up4_2 = Conv2DTranspose(256, (2,2), strides=(2,2), padding='same')(conv5_1)
    up4_2 = concatenate([up4_2, conv4_1], axis=3)
    conv4_2 = Conv2D(256, (3,3), activation=activation, kernel_initializer=he_normal(), padding='same')(up4_2)
    conv4_2 = Conv2D(256, (3,3), activation=activation, kernel_initializer=he_normal(), padding='same')(conv4_2)

    # Third block upsampling
    up3_3 = Conv2DTranspose(128, (2,2), strides=(2,2), padding='same')(conv4_2)
    up3_3 = concatenate([up3_3, conv3_1], axis=3)
    conv3_3 = Conv2D(128, (3,3), activation=activation, kernel_initializer=he_normal(), padding='same')(up3_3)
    conv3_3 = Conv2D(128, (3,3), activation=activation, kernel_initializer=he_normal(), padding='same')(conv3_3)

    # Second block upsampling
    up2_4 = Conv2DTranspose(64, (2,2), strides=(2,2), padding='same')(conv3_3)
    up2_4 = concatenate([up2_4, conv2_1], axis=3)
    conv2_4 = Conv2D(64, (3,3), activation=activation, kernel_initializer=he_normal(), padding='same')(up2_4)
    conv2_4 = Conv2D(64, (3,3), activation=activation, kernel_initializer=he_normal(), padding='same')(conv2_4)

    # First block upsampling
    up1_5 = Conv2DTranspose(32, (2,2), strides=(2,2), padding='same')(conv2_4)
    up1_5 = concatenate([up1_5, conv1_1], axis=3)
    conv1_5 = Conv2D(32, (3,3), activation=activation, kernel_initializer=he_normal(), padding='same')(up1_5)
    conv1_5 = Conv2D(32, (3,3), activation=activation, kernel_initializer=he_normal(), padding='same')(conv1_5)

    # Output block
    outputs = Conv2D(num_classes, (1,1), activation='sigmoid')(conv1_5)

    model = Model(inputs=[inputs], outputs=[outputs])

    return model

# %%
def test_load_image(test_file, target_size=(256,256)):
    img = cv2.imread(test_file, cv2.IMREAD_GRAYSCALE)
    img = img / 255
    img = cv2.resize(img, target_size)
    img = np.reshape(img, img.shape + (1,))
    img = np.reshape(img,(1,) + img.shape)
    return img

def test_generator(test_files, target_size=(256,256)):
    for test_file in test_files:
        yield test_load_image(test_file, target_size)

def save_result(save_path, npyfile, test_files):
    for i, item in enumerate(npyfile):
        result_file = test_files[i]
        img = (item[:, :, 0] * 255.).astype(np.uint8)

        filename, fileext = os.path.splitext(os.path.basename(result_file))

        result_file = os.path.join(save_path, "%s_predict%s" % (filename, fileext))

        cv2.imwrite(result_file, img)

# %%
def add_suffix(base_file, suffix):
    filename, fileext = os.path.splitext(base_file)
    return "%s_%s%s" % (filename, suffix, fileext)

test_files = [test_file for test_file in glob(os.path.join(segmentation_test_dir, "*.png")) \
              if ("_mask" not in test_file \
                  and "_dilate" not in test_file \
                  and "_predict" not in test_file)]

validation_data = (test_load_image(test_files[0], target_size=(256,256)),
                    test_load_image(add_suffix(test_files[0], "dilate"), target_size=(256, 256)))

len(test_files), len(validation_data)
# Out:
# (62, 2)

# %%
r1=test_load_image(test_files[0],target_size=(256,256))
print(r1.shape)
# Out:
# (1, 256, 256, 1)

# %%
train_generator_args = dict(rotation_range=0.2,
                            width_shift_range=0.05,
                            height_shift_range=0.05,
                            shear_range=0.05,
                            zoom_range=0.05,
                            horizontal_flip=True,
                            fill_mode='nearest')

train_gen = train_generator(BATCH_SIZE,
                            segmentation_train_dir,
                            'image',
                            'dilate',
                            train_generator_args,
                            target_size=(256,256),
                            save_to_dir=os.path.abspath(segmentation_aug_dir))

model = unet_plus(input_size=(256,256,1))
model.compile(optimizer=Adam(lr=1e-5), loss=dice_coef_loss, \
                  metrics=[dice_coef, 'binary_accuracy',mean_iou,sensitivity,specificity,precision,recall])
model.summary()

model_checkpoint = ModelCheckpoint('unet_thyroid_seg.hdf5',
                                   monitor='loss',
                                   verbose=1,
                                   save_best_only=True)

history = model.fit(train_gen,
                              steps_per_epoch=len(train_files) / BATCH_SIZE,
                              epochs=EPOCHS,
                              callbacks=[model_checkpoint],
                              validation_data = validation_data)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 32  320         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 32  9248        ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 32  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 64  18496       ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 64  36928       ['conv2d_2[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 64)  0           ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 128)  147584      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 128)  0          ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 256)  295168      ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 256)  590080      ['conv2d_6[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 256)  0          ['conv2d_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 512)  1180160     ['max_pooling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 512)  2359808     ['conv2d_8[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 256)  524544     ['conv2d_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 32, 32, 512)  0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 256)  1179904     ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 256)  590080      ['conv2d_10[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 128)  131200     ['conv2d_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 256)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 128)  295040      ['concatenate_1[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 128)  147584      ['conv2d_12[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 64  32832      ['conv2d_13[0][0]']
#  spose)                         )
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 12  0           ['conv2d_transpose_2[0][0]',
#                                 8)                                'conv2d_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 128, 128, 64  73792       ['concatenate_2[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 128, 128, 64  36928       ['conv2d_14[0][0]']
#                                 )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 256, 256, 32  8224       ['conv2d_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 64  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 256, 256, 32  18464       ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 256, 256, 32  9248        ['conv2d_16[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 256, 256, 1)  33          ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 7,759,521
# Trainable params: 7,759,521
# Non-trainable params: 0
# __________________________________________________________________________________________________
# /usr/local/lib/python3.9/dist-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Found 244 images belonging to 1 classes.
# Found 244 images belonging to 1 classes.
# Epoch 1/60
# 122/122 [==============================] - ETA: 0s - loss: -0.5049 - dice_coef: 0.5049 - binary_accuracy: 0.3781 - mean_iou: 0.3739 - sensitivity: 0.9878 - specificity: 0.0107 - precision: 0.3745 - recall: 0.9878
# Epoch 1: loss improved from inf to -0.50495, saving model to unet_thyroid_seg.hdf5
# 122/122 [==============================] - 28s 106ms/step - loss: -0.5049 - dice_coef: 0.5049 - binary_accuracy: 0.3781 - mean_iou: 0.3739 - sensitivity: 0.9878 - specificity: 0.0107 - precision: 0.3745 - recall: 0.9878 - val_loss: -0.5060 - val_dice_coef: 0.5060 - val_binary_accuracy: 0.3270 - val_mean_iou: 0.3271 - val_sensitivity: 1.0000 - val_specificity: 0.0090 - val_precision: 0.3271 - val_recall: 1.0000
# Epoch 2/60
# 122/122 [==============================] - ETA: 0s - loss: -0.6295 - dice_coef: 0.6295 - binary_accuracy: 0.5620 - mean_iou: 0.4770 - sensitivity: 0.9637 - specificity: 0.3357 - precision: 0.4972 - recall: 0.9637
# Epoch 2: loss improved from -0.50495 to -0.62946, saving model to unet_thyroid_seg.hdf5
# 122/122 [==============================] - 12s 95ms/step - loss: -0.6295 - dice_coef: 0.6295 - binary_accuracy: 0.5620 - mean_iou: 0.4770 - sensitivity: 0.9637 - specificity: 0.3357 - precision: 0.4972 - recall: 0.9637 - val_loss: -0.7888 - val_dice_coef: 0.7888 - val_binary_accuracy: 0.8287 - val_mean_iou: 0.6588 - val_sensitivity: 0.9938 - val_specificity: 0.7551 - val_precision: 0.6616 - val_recall: 0.9938
# Epoch 3/60
# 122/122 [==============================] - ETA: 0s - loss: -0.7895 - dice_coef: 0.7895 - binary_accuracy: 0.8382 - mean_iou: 0.6630 - sensitivity: 0.8736 - specificity: 0.8353 - precision: 0.7515 - recall: 0.8736
# Epoch 3: loss improved from -0.62946 to -0.78948, saving model to unet_thyroid_seg.hdf5
# 122/122 [==============================] - 12s 96ms/step - loss: -0.7895 - dice_coef: 0.7895 - binary_accuracy: 0.8382 - mean_iou: 0.6630 - sensitivity: 0.8736 - specificity: 0.8353 - precision: 0.7515 - recall: 0.8736 - val_loss: -0.8358 - val_dice_coef: 0.8358 - val_binary_accuracy: 0.8719 - val_mean_iou: 0.7200 - val_sensitivity: 0.9849 - val_specificity: 0.8227 - val_precision: 0.7280 - val_recall: 0.9849
# Epoch 4/60
# 122/122 [==============================] - ETA: 0s - loss: -0.7985 - dice_coef: 0.7985 - binary_accuracy: 0.8467 - mean_iou: 0.6727 - sensitivity: 0.8690 - specificity: 0.8519 - precision: 0.7669 - recall: 0.8690
# Epoch 4: loss improved from -0.78948 to -0.79848, saving model to unet_thyroid_seg.hdf5
# 122/122 [==============================] - 12s 101ms/step - loss: -0.7985 - dice_coef: 0.7985 - binary_accuracy: 0.8467 - mean_iou: 0.6727 - sensitivity: 0.8690 - specificity: 0.8519 - precision: 0.7669 - recall: 0.8690 - val_loss: -0.8276 - val_dice_coef: 0.8276 - val_binary_accuracy: 0.8620 - val_mean_iou: 0.7071 - val_sensitivity: 0.9953 - val_specificity: 0.8036 - val_precision: 0.7094 - val_recall: 0.9953
# Epoch 5/60
# 122/122 [==============================] - ETA: 0s - loss: -0.7994 - dice_coef: 0.7994 - binary_accuracy: 0.8471 - mean_iou: 0.6735 - sensitivity: 0.8722 - specificity: 0.8517 - precision: 0.7662 - recall: 0.8722
# Epoch 5: loss improved from -0.79848 to -0.79936, saving model to unet_thyroid_seg.hdf5
# 122/122 [==============================] - 12s 96ms/step - loss: -0.7994 - dice_coef: 0.7994 - binary_accuracy: 0.8471 - mean_iou: 0.6735 - sensitivity: 0.8722 - specificity: 0.8517 - precision: 0.7662 - recall: 0.8722 - val_loss: -0.8650 - val_dice_coef: 0.8650 - val_binary_accuracy: 0.8977 - val_mean_iou: 0.7627 - val_sensitivity: 0.9742 - val_specificity: 0.8664 - val_precision: 0.7783 - val_recall: 0.9742
# Epoch 6/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8010 - dice_coef: 0.8010 - binary_accuracy: 0.8495 - mean_iou: 0.6779 - sensitivity: 0.8737 - specificity: 0.8536 - precision: 0.7689 - recall: 0.8737
# Epoch 6: loss improved from -0.79936 to -0.80098, saving model to unet_thyroid_seg.hdf5
# 122/122 [==============================] - 11s 95ms/step - loss: -0.8010 - dice_coef: 0.8010 - binary_accuracy: 0.8495 - mean_iou: 0.6779 - sensitivity: 0.8737 - specificity: 0.8536 - precision: 0.7689 - recall: 0.8737 - val_loss: -0.8766 - val_dice_coef: 0.8766 - val_binary_accuracy: 0.9097 - val_mean_iou: 0.7808 - val_sensitivity: 0.9482 - val_specificity: 0.8967 - val_precision: 0.8157 - val_recall: 0.9482
# Epoch 7/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8034 - dice_coef: 0.8034 - binary_accuracy: 0.8539 - mean_iou: 0.6812 - sensitivity: 0.8603 - specificity: 0.8655 - precision: 0.7812 - recall: 0.8603
# Epoch 7: loss improved from -0.80098 to -0.80342, saving model to unet_thyroid_seg.hdf5
# 122/122 [==============================] - 11s 93ms/step - loss: -0.8034 - dice_coef: 0.8034 - binary_accuracy: 0.8539 - mean_iou: 0.6812 - sensitivity: 0.8603 - specificity: 0.8655 - precision: 0.7812 - recall: 0.8603 - val_loss: -0.8469 - val_dice_coef: 0.8469 - val_binary_accuracy: 0.8807 - val_mean_iou: 0.7347 - val_sensitivity: 0.9872 - val_specificity: 0.8344 - val_precision: 0.7417 - val_recall: 0.9872
# Epoch 8/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8076 - dice_coef: 0.8076 - binary_accuracy: 0.8551 - mean_iou: 0.6828 - sensitivity: 0.8549 - specificity: 0.8721 - precision: 0.7897 - recall: 0.8549
# Epoch 8: loss improved from -0.80342 to -0.80760, saving model to unet_thyroid_seg.hdf5
# 122/122 [==============================] - 11s 92ms/step - loss: -0.8076 - dice_coef: 0.8076 - binary_accuracy: 0.8551 - mean_iou: 0.6828 - sensitivity: 0.8549 - specificity: 0.8721 - precision: 0.7897 - recall: 0.8549 - val_loss: -0.8392 - val_dice_coef: 0.8392 - val_binary_accuracy: 0.8732 - val_mean_iou: 0.7228 - val_sensitivity: 0.9899 - val_specificity: 0.8219 - val_precision: 0.7281 - val_recall: 0.9899
# Epoch 9/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8126 - dice_coef: 0.8126 - binary_accuracy: 0.8593 - mean_iou: 0.6905 - sensitivity: 0.8610 - specificity: 0.8757 - precision: 0.7931 - recall: 0.8610
# Epoch 9: loss improved from -0.80760 to -0.81263, saving model to unet_thyroid_seg.hdf5
# 122/122 [==============================] - 12s 95ms/step - loss: -0.8126 - dice_coef: 0.8126 - binary_accuracy: 0.8593 - mean_iou: 0.6905 - sensitivity: 0.8610 - specificity: 0.8757 - precision: 0.7931 - recall: 0.8610 - val_loss: -0.8437 - val_dice_coef: 0.8437 - val_binary_accuracy: 0.8768 - val_mean_iou: 0.7293 - val_sensitivity: 0.9926 - val_specificity: 0.8261 - val_precision: 0.7332 - val_recall: 0.9926
# Epoch 10/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8101 - dice_coef: 0.8101 - binary_accuracy: 0.8574 - mean_iou: 0.6867 - sensitivity: 0.8614 - specificity: 0.8760 - precision: 0.7930 - recall: 0.8614
# Epoch 10: loss did not improve from -0.81263
# 122/122 [==============================] - 12s 101ms/step - loss: -0.8101 - dice_coef: 0.8101 - binary_accuracy: 0.8574 - mean_iou: 0.6867 - sensitivity: 0.8614 - specificity: 0.8760 - precision: 0.7930 - recall: 0.8614 - val_loss: -0.8464 - val_dice_coef: 0.8464 - val_binary_accuracy: 0.8793 - val_mean_iou: 0.7333 - val_sensitivity: 0.9918 - val_specificity: 0.8302 - val_precision: 0.7377 - val_recall: 0.9918
# Epoch 11/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8147 - dice_coef: 0.8147 - binary_accuracy: 0.8613 - mean_iou: 0.6933 - sensitivity: 0.8620 - specificity: 0.8768 - precision: 0.7968 - recall: 0.8620
# Epoch 11: loss improved from -0.81263 to -0.81470, saving model to unet_thyroid_seg.hdf5
# 122/122 [==============================] - 12s 96ms/step - loss: -0.8147 - dice_coef: 0.8147 - binary_accuracy: 0.8613 - mean_iou: 0.6933 - sensitivity: 0.8620 - specificity: 0.8768 - precision: 0.7968 - recall: 0.8620 - val_loss: -0.8690 - val_dice_coef: 0.8690 - val_binary_accuracy: 0.9015 - val_mean_iou: 0.7683 - val_sensitivity: 0.9693 - val_specificity: 0.8740 - val_precision: 0.7874 - val_recall: 0.9693
# Epoch 12/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8189 - dice_coef: 0.8189 - binary_accuracy: 0.8658 - mean_iou: 0.6990 - sensitivity: 0.8609 - specificity: 0.8849 - precision: 0.8032 - recall: 0.8609
# Epoch 12: loss improved from -0.81470 to -0.81887, saving model to unet_thyroid_seg.hdf5
# 122/122 [==============================] - 12s 96ms/step - loss: -0.8189 - dice_coef: 0.8189 - binary_accuracy: 0.8658 - mean_iou: 0.6990 - sensitivity: 0.8609 - specificity: 0.8849 - precision: 0.8032 - recall: 0.8609 - val_loss: -0.8832 - val_dice_coef: 0.8832 - val_binary_accuracy: 0.9170 - val_mean_iou: 0.7912 - val_sensitivity: 0.9225 - val_specificity: 0.9200 - val_precision: 0.8475 - val_recall: 0.9225
# Epoch 13/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8174 - dice_coef: 0.8174 - binary_accuracy: 0.8654 - mean_iou: 0.6973 - sensitivity: 0.8601 - specificity: 0.8852 - precision: 0.8057 - recall: 0.8601
# Epoch 13: loss did not improve from -0.81887
# 122/122 [==============================] - 11s 92ms/step - loss: -0.8174 - dice_coef: 0.8174 - binary_accuracy: 0.8654 - mean_iou: 0.6973 - sensitivity: 0.8601 - specificity: 0.8852 - precision: 0.8057 - recall: 0.8601 - val_loss: -0.8835 - val_dice_coef: 0.8835 - val_binary_accuracy: 0.9184 - val_mean_iou: 0.7918 - val_sensitivity: 0.9086 - val_specificity: 0.9290 - val_precision: 0.8604 - val_recall: 0.9086
# Epoch 14/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8169 - dice_coef: 0.8169 - binary_accuracy: 0.8613 - mean_iou: 0.6971 - sensitivity: 0.8725 - specificity: 0.8704 - precision: 0.7938 - recall: 0.8725
# Epoch 14: loss did not improve from -0.81887
# 122/122 [==============================] - 11s 92ms/step - loss: -0.8169 - dice_coef: 0.8169 - binary_accuracy: 0.8613 - mean_iou: 0.6971 - sensitivity: 0.8725 - specificity: 0.8704 - precision: 0.7938 - recall: 0.8725 - val_loss: -0.8758 - val_dice_coef: 0.8758 - val_binary_accuracy: 0.9072 - val_mean_iou: 0.7788 - val_sensitivity: 0.9679 - val_specificity: 0.8831 - val_precision: 0.7996 - val_recall: 0.9679
# Epoch 15/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8299 - dice_coef: 0.8299 - binary_accuracy: 0.8765 - mean_iou: 0.7156 - sensitivity: 0.8608 - specificity: 0.8996 - precision: 0.8247 - recall: 0.8608
# Epoch 15: loss improved from -0.81887 to -0.82991, saving model to unet_thyroid_seg.hdf5
# 122/122 [==============================] - 11s 94ms/step - loss: -0.8299 - dice_coef: 0.8299 - binary_accuracy: 0.8765 - mean_iou: 0.7156 - sensitivity: 0.8608 - specificity: 0.8996 - precision: 0.8247 - recall: 0.8608 - val_loss: -0.8720 - val_dice_coef: 0.8720 - val_binary_accuracy: 0.9066 - val_mean_iou: 0.7730 - val_sensitivity: 0.9409 - val_specificity: 0.8954 - val_precision: 0.8124 - val_recall: 0.9409
# Epoch 16/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8347 - dice_coef: 0.8347 - binary_accuracy: 0.8777 - mean_iou: 0.7212 - sensitivity: 0.8706 - specificity: 0.8950 - precision: 0.8206 - recall: 0.8706
# Epoch 16: loss improved from -0.82991 to -0.83473, saving model to unet_thyroid_seg.hdf5
# 122/122 [==============================] - 12s 99ms/step - loss: -0.8347 - dice_coef: 0.8347 - binary_accuracy: 0.8777 - mean_iou: 0.7212 - sensitivity: 0.8706 - specificity: 0.8950 - precision: 0.8206 - recall: 0.8706 - val_loss: -0.8793 - val_dice_coef: 0.8793 - val_binary_accuracy: 0.9182 - val_mean_iou: 0.7858 - val_sensitivity: 0.8781 - val_specificity: 0.9434 - val_precision: 0.8820 - val_recall: 0.8781
# Epoch 17/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8340 - dice_coef: 0.8340 - binary_accuracy: 0.8775 - mean_iou: 0.7210 - sensitivity: 0.8761 - specificity: 0.8877 - precision: 0.8146 - recall: 0.8761
# Epoch 17: loss did not improve from -0.83473
# 122/122 [==============================] - 11s 93ms/step - loss: -0.8340 - dice_coef: 0.8340 - binary_accuracy: 0.8775 - mean_iou: 0.7210 - sensitivity: 0.8761 - specificity: 0.8877 - precision: 0.8146 - recall: 0.8761 - val_loss: -0.8857 - val_dice_coef: 0.8857 - val_binary_accuracy: 0.9193 - val_mean_iou: 0.7957 - val_sensitivity: 0.9204 - val_specificity: 0.9245 - val_precision: 0.8547 - val_recall: 0.9204
# Epoch 18/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8378 - dice_coef: 0.8378 - binary_accuracy: 0.8812 - mean_iou: 0.7263 - sensitivity: 0.8755 - specificity: 0.8956 - precision: 0.8217 - recall: 0.8755
# Epoch 18: loss improved from -0.83473 to -0.83776, saving model to unet_thyroid_seg.hdf5
# 122/122 [==============================] - 11s 93ms/step - loss: -0.8378 - dice_coef: 0.8378 - binary_accuracy: 0.8812 - mean_iou: 0.7263 - sensitivity: 0.8755 - specificity: 0.8956 - precision: 0.8217 - recall: 0.8755 - val_loss: -0.8741 - val_dice_coef: 0.8741 - val_binary_accuracy: 0.9064 - val_mean_iou: 0.7762 - val_sensitivity: 0.9619 - val_specificity: 0.8848 - val_precision: 0.8009 - val_recall: 0.9619
# Epoch 19/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8445 - dice_coef: 0.8445 - binary_accuracy: 0.8856 - mean_iou: 0.7354 - sensitivity: 0.8752 - specificity: 0.9005 - precision: 0.8319 - recall: 0.8752
# Epoch 19: loss improved from -0.83776 to -0.84447, saving model to unet_thyroid_seg.hdf5
# 122/122 [==============================] - 12s 95ms/step - loss: -0.8445 - dice_coef: 0.8445 - binary_accuracy: 0.8856 - mean_iou: 0.7354 - sensitivity: 0.8752 - specificity: 0.9005 - precision: 0.8319 - recall: 0.8752 - val_loss: -0.8828 - val_dice_coef: 0.8828 - val_binary_accuracy: 0.9216 - val_mean_iou: 0.7906 - val_sensitivity: 0.8655 - val_specificity: 0.9544 - val_precision: 0.9006 - val_recall: 0.8655
# Epoch 20/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8468 - dice_coef: 0.8468 - binary_accuracy: 0.8859 - mean_iou: 0.7384 - sensitivity: 0.8801 - specificity: 0.8979 - precision: 0.8301 - recall: 0.8801
# Epoch 20: loss improved from -0.84447 to -0.84677, saving model to unet_thyroid_seg.hdf5
# 122/122 [==============================] - 12s 96ms/step - loss: -0.8468 - dice_coef: 0.8468 - binary_accuracy: 0.8859 - mean_iou: 0.7384 - sensitivity: 0.8801 - specificity: 0.8979 - precision: 0.8301 - recall: 0.8801 - val_loss: -0.8900 - val_dice_coef: 0.8900 - val_binary_accuracy: 0.9230 - val_mean_iou: 0.8027 - val_sensitivity: 0.9132 - val_specificity: 0.9336 - val_precision: 0.8690 - val_recall: 0.9132
# Epoch 21/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8475 - dice_coef: 0.8475 - binary_accuracy: 0.8882 - mean_iou: 0.7390 - sensitivity: 0.8780 - specificity: 0.9035 - precision: 0.8335 - recall: 0.8780
# Epoch 21: loss improved from -0.84677 to -0.84754, saving model to unet_thyroid_seg.hdf5
# 122/122 [==============================] - 12s 96ms/step - loss: -0.8475 - dice_coef: 0.8475 - binary_accuracy: 0.8882 - mean_iou: 0.7390 - sensitivity: 0.8780 - specificity: 0.9035 - precision: 0.8335 - recall: 0.8780 - val_loss: -0.8447 - val_dice_coef: 0.8447 - val_binary_accuracy: 0.8799 - val_mean_iou: 0.7311 - val_sensitivity: 0.9761 - val_specificity: 0.8386 - val_precision: 0.7445 - val_recall: 0.9761
# Epoch 22/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8507 - dice_coef: 0.8507 - binary_accuracy: 0.8895 - mean_iou: 0.7449 - sensitivity: 0.8862 - specificity: 0.9004 - precision: 0.8322 - recall: 0.8862
# Epoch 22: loss improved from -0.84754 to -0.85074, saving model to unet_thyroid_seg.hdf5
# 122/122 [==============================] - 13s 103ms/step - loss: -0.8507 - dice_coef: 0.8507 - binary_accuracy: 0.8895 - mean_iou: 0.7449 - sensitivity: 0.8862 - specificity: 0.9004 - precision: 0.8322 - recall: 0.8862 - val_loss: -0.8734 - val_dice_coef: 0.8734 - val_binary_accuracy: 0.9098 - val_mean_iou: 0.7754 - val_sensitivity: 0.9175 - val_specificity: 0.9118 - val_precision: 0.8336 - val_recall: 0.9175
# Epoch 23/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8473 - dice_coef: 0.8473 - binary_accuracy: 0.8880 - mean_iou: 0.7401 - sensitivity: 0.8835 - specificity: 0.8996 - precision: 0.8313 - recall: 0.8835
# Epoch 23: loss did not improve from -0.85074
# 122/122 [==============================] - 11s 91ms/step - loss: -0.8473 - dice_coef: 0.8473 - binary_accuracy: 0.8880 - mean_iou: 0.7401 - sensitivity: 0.8835 - specificity: 0.8996 - precision: 0.8313 - recall: 0.8835 - val_loss: -0.8722 - val_dice_coef: 0.8722 - val_binary_accuracy: 0.9185 - val_mean_iou: 0.7736 - val_sensitivity: 0.8172 - val_specificity: 0.9728 - val_precision: 0.9354 - val_recall: 0.8172
# Epoch 24/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8542 - dice_coef: 0.8542 - binary_accuracy: 0.8933 - mean_iou: 0.7489 - sensitivity: 0.8791 - specificity: 0.9071 - precision: 0.8426 - recall: 0.8791
# Epoch 24: loss improved from -0.85074 to -0.85423, saving model to unet_thyroid_seg.hdf5
# 122/122 [==============================] - 11s 94ms/step - loss: -0.8542 - dice_coef: 0.8542 - binary_accuracy: 0.8933 - mean_iou: 0.7489 - sensitivity: 0.8791 - specificity: 0.9071 - precision: 0.8426 - recall: 0.8791 - val_loss: -0.8717 - val_dice_coef: 0.8717 - val_binary_accuracy: 0.9064 - val_mean_iou: 0.7725 - val_sensitivity: 0.9411 - val_specificity: 0.8948 - val_precision: 0.8118 - val_recall: 0.9411
# Epoch 25/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8579 - dice_coef: 0.8579 - binary_accuracy: 0.8951 - mean_iou: 0.7550 - sensitivity: 0.8878 - specificity: 0.9049 - precision: 0.8416 - recall: 0.8878
# Epoch 25: loss improved from -0.85423 to -0.85786, saving model to unet_thyroid_seg.hdf5
# 122/122 [==============================] - 11s 94ms/step - loss: -0.8579 - dice_coef: 0.8579 - binary_accuracy: 0.8951 - mean_iou: 0.7550 - sensitivity: 0.8878 - specificity: 0.9049 - precision: 0.8416 - recall: 0.8878 - val_loss: -0.8669 - val_dice_coef: 0.8669 - val_binary_accuracy: 0.9019 - val_mean_iou: 0.7648 - val_sensitivity: 0.9468 - val_specificity: 0.8853 - val_precision: 0.7992 - val_recall: 0.9468
# Epoch 26/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8554 - dice_coef: 0.8554 - binary_accuracy: 0.8948 - mean_iou: 0.7525 - sensitivity: 0.8889 - specificity: 0.9046 - precision: 0.8394 - recall: 0.8889
# Epoch 26: loss did not improve from -0.85786
# 122/122 [==============================] - 12s 95ms/step - loss: -0.8554 - dice_coef: 0.8554 - binary_accuracy: 0.8948 - mean_iou: 0.7525 - sensitivity: 0.8889 - specificity: 0.9046 - precision: 0.8394 - recall: 0.8889 - val_loss: -0.8864 - val_dice_coef: 0.8864 - val_binary_accuracy: 0.9212 - val_mean_iou: 0.7969 - val_sensitivity: 0.9017 - val_specificity: 0.9366 - val_precision: 0.8728 - val_recall: 0.9017
# Epoch 27/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8587 - dice_coef: 0.8587 - binary_accuracy: 0.8972 - mean_iou: 0.7570 - sensitivity: 0.8880 - specificity: 0.9101 - precision: 0.8472 - recall: 0.8880
# Epoch 27: loss improved from -0.85786 to -0.85875, saving model to unet_thyroid_seg.hdf5
# 122/122 [==============================] - 12s 100ms/step - loss: -0.8587 - dice_coef: 0.8587 - binary_accuracy: 0.8972 - mean_iou: 0.7570 - sensitivity: 0.8880 - specificity: 0.9101 - precision: 0.8472 - recall: 0.8880 - val_loss: -0.8810 - val_dice_coef: 0.8810 - val_binary_accuracy: 0.9173 - val_mean_iou: 0.7878 - val_sensitivity: 0.8999 - val_specificity: 0.9314 - val_precision: 0.8635 - val_recall: 0.8999
# Epoch 28/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8598 - dice_coef: 0.8598 - binary_accuracy: 0.8989 - mean_iou: 0.7600 - sensitivity: 0.8930 - specificity: 0.9096 - precision: 0.8449 - recall: 0.8930
# Epoch 28: loss improved from -0.85875 to -0.85981, saving model to unet_thyroid_seg.hdf5
# 122/122 [==============================] - 12s 96ms/step - loss: -0.8598 - dice_coef: 0.8598 - binary_accuracy: 0.8989 - mean_iou: 0.7600 - sensitivity: 0.8930 - specificity: 0.9096 - precision: 0.8449 - recall: 0.8930 - val_loss: -0.8801 - val_dice_coef: 0.8801 - val_binary_accuracy: 0.9149 - val_mean_iou: 0.7865 - val_sensitivity: 0.9227 - val_specificity: 0.9166 - val_precision: 0.8424 - val_recall: 0.9227
# Epoch 29/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8596 - dice_coef: 0.8596 - binary_accuracy: 0.8984 - mean_iou: 0.7584 - sensitivity: 0.8886 - specificity: 0.9077 - precision: 0.8456 - recall: 0.8886
# Epoch 29: loss did not improve from -0.85981
# 122/122 [==============================] - 12s 96ms/step - loss: -0.8596 - dice_coef: 0.8596 - binary_accuracy: 0.8984 - mean_iou: 0.7584 - sensitivity: 0.8886 - specificity: 0.9077 - precision: 0.8456 - recall: 0.8886 - val_loss: -0.8650 - val_dice_coef: 0.8650 - val_binary_accuracy: 0.9024 - val_mean_iou: 0.7621 - val_sensitivity: 0.9271 - val_specificity: 0.8957 - val_precision: 0.8106 - val_recall: 0.9271
# Epoch 30/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8453 - dice_coef: 0.8453 - binary_accuracy: 0.8851 - mean_iou: 0.7367 - sensitivity: 0.8823 - specificity: 0.8938 - precision: 0.8317 - recall: 0.8823
# Epoch 30: loss did not improve from -0.85981
# 122/122 [==============================] - 11s 91ms/step - loss: -0.8453 - dice_coef: 0.8453 - binary_accuracy: 0.8851 - mean_iou: 0.7367 - sensitivity: 0.8823 - specificity: 0.8938 - precision: 0.8317 - recall: 0.8823 - val_loss: -0.8482 - val_dice_coef: 0.8482 - val_binary_accuracy: 0.8848 - val_mean_iou: 0.7358 - val_sensitivity: 0.9564 - val_specificity: 0.8556 - val_precision: 0.7614 - val_recall: 0.9564
# Epoch 31/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8663 - dice_coef: 0.8663 - binary_accuracy: 0.9021 - mean_iou: 0.7674 - sensitivity: 0.8923 - specificity: 0.9128 - precision: 0.8526 - recall: 0.8923
# Epoch 31: loss improved from -0.85981 to -0.86629, saving model to unet_thyroid_seg.hdf5
# 122/122 [==============================] - 11s 94ms/step - loss: -0.8663 - dice_coef: 0.8663 - binary_accuracy: 0.9021 - mean_iou: 0.7674 - sensitivity: 0.8923 - specificity: 0.9128 - precision: 0.8526 - recall: 0.8923 - val_loss: -0.8496 - val_dice_coef: 0.8496 - val_binary_accuracy: 0.8870 - val_mean_iou: 0.7385 - val_sensitivity: 0.9510 - val_specificity: 0.8614 - val_precision: 0.7677 - val_recall: 0.9510
# Epoch 32/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8666 - dice_coef: 0.8666 - binary_accuracy: 0.9025 - mean_iou: 0.7683 - sensitivity: 0.8938 - specificity: 0.9118 - precision: 0.8516 - recall: 0.8938
# Epoch 32: loss improved from -0.86629 to -0.86655, saving model to unet_thyroid_seg.hdf5
# 122/122 [==============================] - 12s 102ms/step - loss: -0.8666 - dice_coef: 0.8666 - binary_accuracy: 0.9025 - mean_iou: 0.7683 - sensitivity: 0.8938 - specificity: 0.9118 - precision: 0.8516 - recall: 0.8938 - val_loss: -0.8503 - val_dice_coef: 0.8503 - val_binary_accuracy: 0.8897 - val_mean_iou: 0.7393 - val_sensitivity: 0.9320 - val_specificity: 0.8744 - val_precision: 0.7815 - val_recall: 0.9320
# Epoch 33/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8664 - dice_coef: 0.8664 - binary_accuracy: 0.9036 - mean_iou: 0.7688 - sensitivity: 0.8959 - specificity: 0.9120 - precision: 0.8504 - recall: 0.8959
# Epoch 33: loss did not improve from -0.86655
# 122/122 [==============================] - 12s 95ms/step - loss: -0.8664 - dice_coef: 0.8664 - binary_accuracy: 0.9036 - mean_iou: 0.7688 - sensitivity: 0.8959 - specificity: 0.9120 - precision: 0.8504 - recall: 0.8959 - val_loss: -0.8863 - val_dice_coef: 0.8863 - val_binary_accuracy: 0.9227 - val_mean_iou: 0.7976 - val_sensitivity: 0.8863 - val_specificity: 0.9464 - val_precision: 0.8887 - val_recall: 0.8863
# Epoch 34/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8678 - dice_coef: 0.8678 - binary_accuracy: 0.9043 - mean_iou: 0.7705 - sensitivity: 0.8910 - specificity: 0.9152 - precision: 0.8551 - recall: 0.8910
# Epoch 34: loss improved from -0.86655 to -0.86776, saving model to unet_thyroid_seg.hdf5
# 122/122 [==============================] - 12s 95ms/step - loss: -0.8678 - dice_coef: 0.8678 - binary_accuracy: 0.9043 - mean_iou: 0.7705 - sensitivity: 0.8910 - specificity: 0.9152 - precision: 0.8551 - recall: 0.8910 - val_loss: -0.8898 - val_dice_coef: 0.8898 - val_binary_accuracy: 0.9253 - val_mean_iou: 0.8024 - val_sensitivity: 0.8829 - val_specificity: 0.9517 - val_precision: 0.8979 - val_recall: 0.8829
# Epoch 35/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8630 - dice_coef: 0.8630 - binary_accuracy: 0.8999 - mean_iou: 0.7635 - sensitivity: 0.8881 - specificity: 0.9128 - precision: 0.8526 - recall: 0.8881
# Epoch 35: loss did not improve from -0.86776
# 122/122 [==============================] - 11s 93ms/step - loss: -0.8630 - dice_coef: 0.8630 - binary_accuracy: 0.8999 - mean_iou: 0.7635 - sensitivity: 0.8881 - specificity: 0.9128 - precision: 0.8526 - recall: 0.8881 - val_loss: -0.8508 - val_dice_coef: 0.8508 - val_binary_accuracy: 0.8901 - val_mean_iou: 0.7397 - val_sensitivity: 0.9306 - val_specificity: 0.8756 - val_precision: 0.7827 - val_recall: 0.9306
# Epoch 36/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8659 - dice_coef: 0.8659 - binary_accuracy: 0.9022 - mean_iou: 0.7673 - sensitivity: 0.8955 - specificity: 0.9111 - precision: 0.8517 - recall: 0.8955
# Epoch 36: loss did not improve from -0.86776
# 122/122 [==============================] - 11s 89ms/step - loss: -0.8659 - dice_coef: 0.8659 - binary_accuracy: 0.9022 - mean_iou: 0.7673 - sensitivity: 0.8955 - specificity: 0.9111 - precision: 0.8517 - recall: 0.8955 - val_loss: -0.8739 - val_dice_coef: 0.8739 - val_binary_accuracy: 0.9117 - val_mean_iou: 0.7763 - val_sensitivity: 0.9038 - val_specificity: 0.9209 - val_precision: 0.8465 - val_recall: 0.9038
# Epoch 37/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8667 - dice_coef: 0.8667 - binary_accuracy: 0.9039 - mean_iou: 0.7694 - sensitivity: 0.8927 - specificity: 0.9135 - precision: 0.8527 - recall: 0.8927
# Epoch 37: loss did not improve from -0.86776
# 122/122 [==============================] - 11s 93ms/step - loss: -0.8667 - dice_coef: 0.8667 - binary_accuracy: 0.9039 - mean_iou: 0.7694 - sensitivity: 0.8927 - specificity: 0.9135 - precision: 0.8527 - recall: 0.8927 - val_loss: -0.8799 - val_dice_coef: 0.8799 - val_binary_accuracy: 0.9151 - val_mean_iou: 0.7860 - val_sensitivity: 0.9176 - val_specificity: 0.9193 - val_precision: 0.8456 - val_recall: 0.9176
# Epoch 38/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8485 - dice_coef: 0.8485 - binary_accuracy: 0.8892 - mean_iou: 0.7432 - sensitivity: 0.8856 - specificity: 0.8976 - precision: 0.8349 - recall: 0.8856
# Epoch 38: loss did not improve from -0.86776
# 122/122 [==============================] - 12s 101ms/step - loss: -0.8485 - dice_coef: 0.8485 - binary_accuracy: 0.8892 - mean_iou: 0.7432 - sensitivity: 0.8856 - specificity: 0.8976 - precision: 0.8349 - recall: 0.8856 - val_loss: -0.8187 - val_dice_coef: 0.8187 - val_binary_accuracy: 0.8582 - val_mean_iou: 0.6926 - val_sensitivity: 0.9583 - val_specificity: 0.8152 - val_precision: 0.7142 - val_recall: 0.9583
# Epoch 39/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8636 - dice_coef: 0.8636 - binary_accuracy: 0.9006 - mean_iou: 0.7650 - sensitivity: 0.8953 - specificity: 0.9112 - precision: 0.8486 - recall: 0.8953
# Epoch 39: loss did not improve from -0.86776
# 122/122 [==============================] - 11s 93ms/step - loss: -0.8636 - dice_coef: 0.8636 - binary_accuracy: 0.9006 - mean_iou: 0.7650 - sensitivity: 0.8953 - specificity: 0.9112 - precision: 0.8486 - recall: 0.8953 - val_loss: -0.8756 - val_dice_coef: 0.8756 - val_binary_accuracy: 0.9133 - val_mean_iou: 0.7787 - val_sensitivity: 0.8980 - val_specificity: 0.9262 - val_precision: 0.8544 - val_recall: 0.8980
# Epoch 40/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8666 - dice_coef: 0.8666 - binary_accuracy: 0.9059 - mean_iou: 0.7723 - sensitivity: 0.8924 - specificity: 0.9136 - precision: 0.8516 - recall: 0.8924
# Epoch 40: loss did not improve from -0.86776
# 122/122 [==============================] - 10s 86ms/step - loss: -0.8666 - dice_coef: 0.8666 - binary_accuracy: 0.9059 - mean_iou: 0.7723 - sensitivity: 0.8924 - specificity: 0.9136 - precision: 0.8516 - recall: 0.8924 - val_loss: -0.8887 - val_dice_coef: 0.8887 - val_binary_accuracy: 0.9239 - val_mean_iou: 0.8011 - val_sensitivity: 0.8916 - val_specificity: 0.9456 - val_precision: 0.8879 - val_recall: 0.8916
# Epoch 41/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8642 - dice_coef: 0.8642 - binary_accuracy: 0.9011 - mean_iou: 0.7650 - sensitivity: 0.8906 - specificity: 0.9094 - precision: 0.8504 - recall: 0.8906
# Epoch 41: loss did not improve from -0.86776
# 122/122 [==============================] - 12s 96ms/step - loss: -0.8642 - dice_coef: 0.8642 - binary_accuracy: 0.9011 - mean_iou: 0.7650 - sensitivity: 0.8906 - specificity: 0.9094 - precision: 0.8504 - recall: 0.8906 - val_loss: -0.8841 - val_dice_coef: 0.8841 - val_binary_accuracy: 0.9220 - val_mean_iou: 0.7929 - val_sensitivity: 0.8685 - val_specificity: 0.9541 - val_precision: 0.9011 - val_recall: 0.8685
# Epoch 42/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8697 - dice_coef: 0.8697 - binary_accuracy: 0.9064 - mean_iou: 0.7732 - sensitivity: 0.8928 - specificity: 0.9192 - precision: 0.8592 - recall: 0.8928
# Epoch 42: loss improved from -0.86776 to -0.86971, saving model to unet_thyroid_seg.hdf5
# 122/122 [==============================] - 11s 93ms/step - loss: -0.8697 - dice_coef: 0.8697 - binary_accuracy: 0.9064 - mean_iou: 0.7732 - sensitivity: 0.8928 - specificity: 0.9192 - precision: 0.8592 - recall: 0.8928 - val_loss: -0.8828 - val_dice_coef: 0.8828 - val_binary_accuracy: 0.9219 - val_mean_iou: 0.7909 - val_sensitivity: 0.8613 - val_specificity: 0.9571 - val_precision: 0.9065 - val_recall: 0.8613
# Epoch 43/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8705 - dice_coef: 0.8705 - binary_accuracy: 0.9056 - mean_iou: 0.7743 - sensitivity: 0.8951 - specificity: 0.9144 - precision: 0.8562 - recall: 0.8951
# Epoch 43: loss improved from -0.86971 to -0.87045, saving model to unet_thyroid_seg.hdf5
# 122/122 [==============================] - 12s 96ms/step - loss: -0.8705 - dice_coef: 0.8705 - binary_accuracy: 0.9056 - mean_iou: 0.7743 - sensitivity: 0.8951 - specificity: 0.9144 - precision: 0.8562 - recall: 0.8951 - val_loss: -0.8573 - val_dice_coef: 0.8573 - val_binary_accuracy: 0.8944 - val_mean_iou: 0.7502 - val_sensitivity: 0.9421 - val_specificity: 0.8768 - val_precision: 0.7865 - val_recall: 0.9421
# Epoch 44/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8674 - dice_coef: 0.8674 - binary_accuracy: 0.9026 - mean_iou: 0.7700 - sensitivity: 0.8952 - specificity: 0.9123 - precision: 0.8541 - recall: 0.8952
# Epoch 44: loss did not improve from -0.87045
# 122/122 [==============================] - 12s 96ms/step - loss: -0.8674 - dice_coef: 0.8674 - binary_accuracy: 0.9026 - mean_iou: 0.7700 - sensitivity: 0.8952 - specificity: 0.9123 - precision: 0.8541 - recall: 0.8952 - val_loss: -0.8821 - val_dice_coef: 0.8821 - val_binary_accuracy: 0.9175 - val_mean_iou: 0.7890 - val_sensitivity: 0.9070 - val_specificity: 0.9279 - val_precision: 0.8584 - val_recall: 0.9070
# Epoch 45/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8690 - dice_coef: 0.8690 - binary_accuracy: 0.9038 - mean_iou: 0.7716 - sensitivity: 0.8939 - specificity: 0.9148 - precision: 0.8577 - recall: 0.8939
# Epoch 45: loss did not improve from -0.87045
# 122/122 [==============================] - 11s 87ms/step - loss: -0.8690 - dice_coef: 0.8690 - binary_accuracy: 0.9038 - mean_iou: 0.7716 - sensitivity: 0.8939 - specificity: 0.9148 - precision: 0.8577 - recall: 0.8939 - val_loss: -0.8446 - val_dice_coef: 0.8446 - val_binary_accuracy: 0.8852 - val_mean_iou: 0.7310 - val_sensitivity: 0.9295 - val_specificity: 0.8692 - val_precision: 0.7739 - val_recall: 0.9295
# Epoch 46/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8687 - dice_coef: 0.8687 - binary_accuracy: 0.9046 - mean_iou: 0.7718 - sensitivity: 0.8965 - specificity: 0.9139 - precision: 0.8543 - recall: 0.8965
# Epoch 46: loss did not improve from -0.87045
# 122/122 [==============================] - 11s 90ms/step - loss: -0.8687 - dice_coef: 0.8687 - binary_accuracy: 0.9046 - mean_iou: 0.7718 - sensitivity: 0.8965 - specificity: 0.9139 - precision: 0.8543 - recall: 0.8965 - val_loss: -0.8759 - val_dice_coef: 0.8759 - val_binary_accuracy: 0.9139 - val_mean_iou: 0.7794 - val_sensitivity: 0.8947 - val_specificity: 0.9287 - val_precision: 0.8581 - val_recall: 0.8947
# Epoch 47/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8719 - dice_coef: 0.8719 - binary_accuracy: 0.9066 - mean_iou: 0.7760 - sensitivity: 0.8925 - specificity: 0.9179 - precision: 0.8621 - recall: 0.8925
# Epoch 47: loss improved from -0.87045 to -0.87185, saving model to unet_thyroid_seg.hdf5
# 122/122 [==============================] - 13s 107ms/step - loss: -0.8719 - dice_coef: 0.8719 - binary_accuracy: 0.9066 - mean_iou: 0.7760 - sensitivity: 0.8925 - specificity: 0.9179 - precision: 0.8621 - recall: 0.8925 - val_loss: -0.8686 - val_dice_coef: 0.8686 - val_binary_accuracy: 0.9091 - val_mean_iou: 0.7686 - val_sensitivity: 0.8903 - val_specificity: 0.9237 - val_precision: 0.8491 - val_recall: 0.8903
# Epoch 48/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8651 - dice_coef: 0.8651 - binary_accuracy: 0.9025 - mean_iou: 0.7666 - sensitivity: 0.8917 - specificity: 0.9105 - precision: 0.8524 - recall: 0.8917
# Epoch 48: loss did not improve from -0.87185
# 122/122 [==============================] - 11s 93ms/step - loss: -0.8651 - dice_coef: 0.8651 - binary_accuracy: 0.9025 - mean_iou: 0.7666 - sensitivity: 0.8917 - specificity: 0.9105 - precision: 0.8524 - recall: 0.8917 - val_loss: -0.8659 - val_dice_coef: 0.8659 - val_binary_accuracy: 0.9029 - val_mean_iou: 0.7635 - val_sensitivity: 0.9285 - val_specificity: 0.8959 - val_precision: 0.8112 - val_recall: 0.9285
# Epoch 49/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8617 - dice_coef: 0.8617 - binary_accuracy: 0.8988 - mean_iou: 0.7616 - sensitivity: 0.8908 - specificity: 0.9062 - precision: 0.8494 - recall: 0.8908
# Epoch 49: loss did not improve from -0.87185
# 122/122 [==============================] - 12s 98ms/step - loss: -0.8617 - dice_coef: 0.8617 - binary_accuracy: 0.8988 - mean_iou: 0.7616 - sensitivity: 0.8908 - specificity: 0.9062 - precision: 0.8494 - recall: 0.8908 - val_loss: -0.8689 - val_dice_coef: 0.8689 - val_binary_accuracy: 0.9045 - val_mean_iou: 0.7683 - val_sensitivity: 0.9368 - val_specificity: 0.8943 - val_precision: 0.8103 - val_recall: 0.9368
# Epoch 50/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8749 - dice_coef: 0.8749 - binary_accuracy: 0.9092 - mean_iou: 0.7814 - sensitivity: 0.9002 - specificity: 0.9187 - precision: 0.8614 - recall: 0.9002
# Epoch 50: loss improved from -0.87185 to -0.87495, saving model to unet_thyroid_seg.hdf5
# 122/122 [==============================] - 11s 94ms/step - loss: -0.8749 - dice_coef: 0.8749 - binary_accuracy: 0.9092 - mean_iou: 0.7814 - sensitivity: 0.9002 - specificity: 0.9187 - precision: 0.8614 - recall: 0.9002 - val_loss: -0.8806 - val_dice_coef: 0.8806 - val_binary_accuracy: 0.9205 - val_mean_iou: 0.7873 - val_sensitivity: 0.8610 - val_specificity: 0.9549 - val_precision: 0.9021 - val_recall: 0.8610
# Epoch 51/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8723 - dice_coef: 0.8723 - binary_accuracy: 0.9081 - mean_iou: 0.7776 - sensitivity: 0.8905 - specificity: 0.9228 - precision: 0.8664 - recall: 0.8905
# Epoch 51: loss did not improve from -0.87495
# 122/122 [==============================] - 11s 87ms/step - loss: -0.8723 - dice_coef: 0.8723 - binary_accuracy: 0.9081 - mean_iou: 0.7776 - sensitivity: 0.8905 - specificity: 0.9228 - precision: 0.8664 - recall: 0.8905 - val_loss: -0.8286 - val_dice_coef: 0.8286 - val_binary_accuracy: 0.8682 - val_mean_iou: 0.7073 - val_sensitivity: 0.9531 - val_specificity: 0.8326 - val_precision: 0.7329 - val_recall: 0.9531
# Epoch 52/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8657 - dice_coef: 0.8657 - binary_accuracy: 0.9009 - mean_iou: 0.7673 - sensitivity: 0.9023 - specificity: 0.9003 - precision: 0.8461 - recall: 0.9023
# Epoch 52: loss did not improve from -0.87495
# 122/122 [==============================] - 12s 97ms/step - loss: -0.8657 - dice_coef: 0.8657 - binary_accuracy: 0.9009 - mean_iou: 0.7673 - sensitivity: 0.9023 - specificity: 0.9003 - precision: 0.8461 - recall: 0.9023 - val_loss: -0.8683 - val_dice_coef: 0.8683 - val_binary_accuracy: 0.9063 - val_mean_iou: 0.7670 - val_sensitivity: 0.9129 - val_specificity: 0.9084 - val_precision: 0.8277 - val_recall: 0.9129
# Epoch 53/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8727 - dice_coef: 0.8727 - binary_accuracy: 0.9073 - mean_iou: 0.7771 - sensitivity: 0.8942 - specificity: 0.9212 - precision: 0.8627 - recall: 0.8942
# Epoch 53: loss did not improve from -0.87495
# 122/122 [==============================] - 11s 93ms/step - loss: -0.8727 - dice_coef: 0.8727 - binary_accuracy: 0.9073 - mean_iou: 0.7771 - sensitivity: 0.8942 - specificity: 0.9212 - precision: 0.8627 - recall: 0.8942 - val_loss: -0.8816 - val_dice_coef: 0.8816 - val_binary_accuracy: 0.9174 - val_mean_iou: 0.7880 - val_sensitivity: 0.9020 - val_specificity: 0.9303 - val_precision: 0.8618 - val_recall: 0.9020
# Epoch 54/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8765 - dice_coef: 0.8765 - binary_accuracy: 0.9090 - mean_iou: 0.7831 - sensitivity: 0.9008 - specificity: 0.9179 - precision: 0.8628 - recall: 0.9008
# Epoch 54: loss improved from -0.87495 to -0.87653, saving model to unet_thyroid_seg.hdf5
# 122/122 [==============================] - 12s 96ms/step - loss: -0.8765 - dice_coef: 0.8765 - binary_accuracy: 0.9090 - mean_iou: 0.7831 - sensitivity: 0.9008 - specificity: 0.9179 - precision: 0.8628 - recall: 0.9008 - val_loss: -0.8791 - val_dice_coef: 0.8791 - val_binary_accuracy: 0.9179 - val_mean_iou: 0.7850 - val_sensitivity: 0.8748 - val_specificity: 0.9449 - val_precision: 0.8845 - val_recall: 0.8748
# Epoch 55/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8668 - dice_coef: 0.8668 - binary_accuracy: 0.9035 - mean_iou: 0.7689 - sensitivity: 0.8902 - specificity: 0.9143 - precision: 0.8570 - recall: 0.8902
# Epoch 55: loss did not improve from -0.87653
# 122/122 [==============================] - 12s 96ms/step - loss: -0.8668 - dice_coef: 0.8668 - binary_accuracy: 0.9035 - mean_iou: 0.7689 - sensitivity: 0.8902 - specificity: 0.9143 - precision: 0.8570 - recall: 0.8902 - val_loss: -0.8660 - val_dice_coef: 0.8660 - val_binary_accuracy: 0.9150 - val_mean_iou: 0.7636 - val_sensitivity: 0.8045 - val_specificity: 0.9742 - val_precision: 0.9376 - val_recall: 0.8045
# Epoch 56/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8165 - dice_coef: 0.8165 - binary_accuracy: 0.8563 - mean_iou: 0.6981 - sensitivity: 0.8832 - specificity: 0.8492 - precision: 0.7894 - recall: 0.8832
# Epoch 56: loss did not improve from -0.87653
# 122/122 [==============================] - 10s 85ms/step - loss: -0.8165 - dice_coef: 0.8165 - binary_accuracy: 0.8563 - mean_iou: 0.6981 - sensitivity: 0.8832 - specificity: 0.8492 - precision: 0.7894 - recall: 0.8832 - val_loss: -0.8580 - val_dice_coef: 0.8580 - val_binary_accuracy: 0.8948 - val_mean_iou: 0.7515 - val_sensitivity: 0.9441 - val_specificity: 0.8765 - val_precision: 0.7865 - val_recall: 0.9441
# Epoch 57/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8441 - dice_coef: 0.8441 - binary_accuracy: 0.8847 - mean_iou: 0.7355 - sensitivity: 0.8801 - specificity: 0.9016 - precision: 0.8288 - recall: 0.8801
# Epoch 57: loss did not improve from -0.87653
# 122/122 [==============================] - 11s 93ms/step - loss: -0.8441 - dice_coef: 0.8441 - binary_accuracy: 0.8847 - mean_iou: 0.7355 - sensitivity: 0.8801 - specificity: 0.9016 - precision: 0.8288 - recall: 0.8801 - val_loss: -0.8795 - val_dice_coef: 0.8795 - val_binary_accuracy: 0.9212 - val_mean_iou: 0.7851 - val_sensitivity: 0.8390 - val_specificity: 0.9669 - val_precision: 0.9239 - val_recall: 0.8390
# Epoch 58/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8708 - dice_coef: 0.8708 - binary_accuracy: 0.9060 - mean_iou: 0.7749 - sensitivity: 0.8918 - specificity: 0.9192 - precision: 0.8610 - recall: 0.8918
# Epoch 58: loss did not improve from -0.87653
# 122/122 [==============================] - 12s 99ms/step - loss: -0.8708 - dice_coef: 0.8708 - binary_accuracy: 0.9060 - mean_iou: 0.7749 - sensitivity: 0.8918 - specificity: 0.9192 - precision: 0.8610 - recall: 0.8918 - val_loss: -0.8464 - val_dice_coef: 0.8464 - val_binary_accuracy: 0.8879 - val_mean_iou: 0.7334 - val_sensitivity: 0.9193 - val_specificity: 0.8779 - val_precision: 0.7839 - val_recall: 0.9193
# Epoch 59/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8752 - dice_coef: 0.8752 - binary_accuracy: 0.9096 - mean_iou: 0.7820 - sensitivity: 0.8973 - specificity: 0.9212 - precision: 0.8648 - recall: 0.8973
# Epoch 59: loss did not improve from -0.87653
# 122/122 [==============================] - 11s 94ms/step - loss: -0.8752 - dice_coef: 0.8752 - binary_accuracy: 0.9096 - mean_iou: 0.7820 - sensitivity: 0.8973 - specificity: 0.9212 - precision: 0.8648 - recall: 0.8973 - val_loss: -0.8772 - val_dice_coef: 0.8772 - val_binary_accuracy: 0.9151 - val_mean_iou: 0.7815 - val_sensitivity: 0.8936 - val_specificity: 0.9309 - val_precision: 0.8617 - val_recall: 0.8936
# Epoch 60/60
# 122/122 [==============================] - ETA: 0s - loss: -0.8767 - dice_coef: 0.8767 - binary_accuracy: 0.9095 - mean_iou: 0.7827 - sensitivity: 0.8981 - specificity: 0.9195 - precision: 0.8653 - recall: 0.8981
# Epoch 60: loss improved from -0.87653 to -0.87670, saving model to unet_thyroid_seg.hdf5
# 122/122 [==============================] - 11s 93ms/step - loss: -0.8767 - dice_coef: 0.8767 - binary_accuracy: 0.9095 - mean_iou: 0.7827 - sensitivity: 0.8981 - specificity: 0.9195 - precision: 0.8653 - recall: 0.8981 - val_loss: -0.8459 - val_dice_coef: 0.8459 - val_binary_accuracy: 0.8869 - val_mean_iou: 0.7328 - val_sensitivity: 0.9236 - val_specificity: 0.8745 - val_precision: 0.7800 - val_recall: 0.9236

# %%
fig, axs = plt.subplots(1, 2, figsize = (15, 4))

training_loss = history.history['loss']
validation_loss = history.history['val_loss']

training_accuracy = history.history['binary_accuracy']
validation_accuracy = history.history['val_binary_accuracy']

epoch_count = range(1, len(training_loss) + 1)

axs[0].plot(epoch_count, training_loss, 'r--')
axs[0].plot(epoch_count, validation_loss, 'b-')
axs[0].legend(['Training Loss', 'Validation Loss'])

axs[1].plot(epoch_count, training_accuracy, 'r--')
axs[1].plot(epoch_count, validation_accuracy, 'b-')
axs[1].legend(['Training Accuracy', 'Validation Accuracy'])

# %%
fig, axs = plt.subplots(1, 2, figsize = (15, 4))

training_recall = history.history['recall']
validation_recall = history.history['val_recall']

training_precision = history.history['precision']
validation_precision = history.history['val_precision']

epoch_count = range(1, len(training_loss) + 1)

axs[1].plot(epoch_count, training_precision, 'r--')
axs[1].plot(epoch_count, validation_precision, 'b-')
axs[1].legend(['Training precision', 'Validation precision'])

# %%
fig, axs = plt.subplots(1, 2, figsize = (15, 4))

training_mean_iou = history.history['mean_iou']
validation_mean_iou = history.history['val_mean_iou']

training_specificity = history.history['specificity']
validation_specificity = history.history['val_specificity']

epoch_count = range(1, len(training_loss) + 1)

axs[0].plot(epoch_count, training_mean_iou, 'r--')
axs[0].plot(epoch_count, validation_mean_iou, 'b-')
axs[0].legend(['Training mean_iou', 'Validation mean_iou'])

axs[1].plot(epoch_count, training_specificity, 'r--')
axs[1].plot(epoch_count, validation_specificity, 'b-')
axs[1].legend(['Training specificity', 'Validation specificity'])

# %%
fig, axs = plt.subplots(1, 2, figsize = (15, 4))

training_dice_coef = history.history['dice_coef']
validation_dice_coef = history.history['val_dice_coef']

training_sensitivity = history.history['sensitivity']
validation_sensitivity = history.history['val_sensitivity']

epoch_count = range(1, len(training_loss) + 1)

axs[0].plot(epoch_count, training_dice_coef, 'r--')
axs[0].plot(epoch_count, validation_dice_coef, 'b-')
axs[0].legend(['Training dice_coef', 'Validation dice_coef'])

# %%
test_gen = test_generator(test_files, target_size=(256,256))
results = model.predict_generator(test_gen, len(test_files), verbose=1)
save_result(segmentation_test_dir, results, test_files)
# Out:
# <ipython-input-26-413e009a05ca>:2: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   results = model.predict_generator(test_gen, len(test_files), verbose=1)
# 62/62 [==============================] - 1s 9ms/step

# %%
image = cv2.imread("/content/drive/MyDrive/research/segmentation/test++/118.png")
predict_image = cv2.imread("/content/drive/MyDrive/research/segmentation/test++/118_mask.png")
mask_image = cv2.imread("/content/drive/MyDrive/research/segmentation/test++/118_dilate.png")

fig, axs = plt.subplots(4, 3, figsize=(16, 16))

axs[0, 0].set_title("Predicted")
axs[0, 0].imshow(add_colored_mask(image, predict_image))
axs[0, 1].set_title("Gold Std.")
axs[0, 1].imshow(add_colored_mask(image, mask_image))
axs[0, 2].set_title("Diff.")
axs[0, 2].imshow(diff_mask(mask_image, predict_image))

image = cv2.imread("/content/drive/MyDrive/research/segmentation/test++/119.png")
predict_image = cv2.imread("/content/drive/MyDrive/research/segmentation/test++/119_mask.png")
mask_image = cv2.imread("/content/drive/MyDrive/research/segmentation/test++/119_dilate.png")

axs[1, 0].set_title("Predicted")
axs[1, 0].imshow(add_colored_mask(image, predict_image))
axs[1, 1].set_title("Gold Std.")
axs[1, 1].imshow(add_colored_mask(image, mask_image))
axs[1, 2].set_title("Diff.")
axs[1, 2].imshow(diff_mask(mask_image, predict_image))

image = cv2.imread("/content/drive/MyDrive/research/segmentation/test++/137.png")
predict_image = cv2.imread("/content/drive/MyDrive/research/segmentation/test++/137_mask.png")
mask_image = cv2.imread("/content/drive/MyDrive/research/segmentation/test++/137_dilate.png")

axs[2, 0].set_title("Predicted")
axs[2, 0].imshow(add_colored_mask(image, predict_image))
axs[2, 1].set_title("Gold Std.")
axs[2, 1].imshow(add_colored_mask(image, mask_image))
axs[2, 2].set_title("Diff.")
axs[2, 2].imshow(diff_mask(mask_image, predict_image))

image = cv2.imread("/content/drive/MyDrive/research/segmentation/test++/125.png")
predict_image = cv2.imread("/content/drive/MyDrive/research/segmentation/test++/125_mask.png")
mask_image = cv2.imread("/content/drive/MyDrive/research/segmentation/test++/125_dilate.png")

axs[3, 0].set_title("Predicted")
axs[3, 0].imshow(add_colored_mask(image, predict_image))
axs[3, 1].set_title("Gold Std.")
axs[3, 1].imshow(add_colored_mask(image, mask_image))
axs[3, 2].set_title("Diff.")
axs[3, 2].imshow(diff_mask(mask_image, predict_image))
